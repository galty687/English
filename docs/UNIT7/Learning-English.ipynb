# %%
import requests

def download_mp3(url, filename):
    response = requests.get(url)
    with open(filename, 'wb') as file:
        file.write(response.content)

# British English Pronunciations
download_mp3('https://s3.eu-west-1.amazonaws.com/com.idmgroup.oed100.sounds.prod/mp3/m/ma/mas/mastermind__gb_2.mp3', 'mastermind_british_1.mp3')
download_mp3('https://s3.eu-west-1.amazonaws.com/com.idmgroup.oed100.sounds.prod/mp3/m/ma/mas/mastermind__gb_4.mp3', 'mastermind_british_2.mp3')

# U.S. English Pronunciation
download_mp3('https://s3.eu-west-1.amazonaws.com/com.idmgroup.oed100.sounds.prod/mp3/m/ma/mas/mastermind__us_4.mp3', 'mastermind_american.mp3')

# %%
from string import Template

# Define the HTML template
with open("template.html", "r") as f:
    template_str = f.read()
    template = Template(template_str)

# Define the word entry template
word_entry_template = Template("""
<div class="word-container">
    <div class="word">$word</div>
    <div class="pronunciation-container">
        <div class="pronunciation-box">
            <div class="pronunciation-label">British Pronunciation</div>
            <div class="pronunciation">$british_pronunciation</div>
            <button class="play-button" onclick="playSound('$british_audio_id')">Play Sound</button>
            <audio id="$british_audio_id" src="$british_audio_src"></audio>
        </div>
        <div class="pronunciation-box">
            <div class="pronunciation-label">American Pronunciation</div>
            <div class="pronunciation">$american_pronunciation</div>
            <button class="play-button" onclick="playSound('$american_audio_id')">Play Sound</button>
            <audio id="$american_audio_id" src="$american_audio_src"></audio>
        </div>
    </div>
    <div class="sentence">$sentence</div>
</div>
""")

# Sample data
data = [
    {
        "word": "pry",
        "british_pronunciation": "/praɪ/",
        "british_audio_src": "pry_gb.mp3",
        "american_pronunciation": "/praɪ/",
        "american_audio_src": "pry_us.mp3",
        "sentence": "with its contents kept safe from prying eyes"
    },
    {
        "word": "wiretap",
        "british_pronunciation": "/ˈwaɪə.tæp/",
        "british_audio_src": "wiretap_gb.mp3",
        "american_pronunciation": "/ˈwaɪɚ.tæp/",
        "american_audio_src": "wiretap_us.mp3",
        "sentence": "you might assume that your conversation will proceed unmonitored by wiretaps or other listening devices."
    },{
        "word": "prohibits",
        "british_pronunciation": "/prəˈhɪb.ɪts/",
        "british_audio_src": "prohibits_gb.mp3",
        "american_pronunciation": "/prəˈhɪb.ɪts/",
        "american_audio_src": "prohibits_us.mp3",
        "sentence": "the Electronic Communications Privacy Act of 2000 prohibits the use of intercepted e-mail as evidence"
    },
    {
        "word": "intercept",
        "british_pronunciation": "/ˈɪn.tə.sept/",
        "british_audio_src": "intercept_gb.mp3",
        "american_pronunciation": "/ˈɪn.tɚ.sept/",
        "american_audio_src": "intercept_us.mp3",
        "sentence": "the Electronic Communications Privacy Act of 2000 prohibits the use of intercepted e-mail as evidence"
    },
    {
        "word": "warrant",
        "british_pronunciation": "/ˈwɒr.ənt/",
        "british_audio_src": "warrant_gb.mp3",
        "american_pronunciation": "/ˈwɔːr.ənt/",
        "american_audio_src": "warrant_us.mp3",
        "sentence": "unless a judge approved a search warrant"
    },
    {
        "word": "ISP",
        "british_pronunciation": "/ˌaɪ.esˈpiː/",
        "british_audio_src": "ISP_gb.mp3",
        "american_pronunciation": "/ˌaɪ.esˈpiː/",
        "american_audio_src": "ISP_us.mp3",
        "sentence": "obtaining a court order to compel an ISP to produce e-mail logs and addresses"
    },{
        "word": "eavesdrop",
        "british_pronunciation": "/ˈiːvz.drɒp/",
        "british_audio_src": "eavesdrop_gb.mp3",
        "american_pronunciation": "/ˈiːvz.drɑːp/",
        "american_audio_src": "eavesdrop_us.mp3",
        "sentence": "To eavesdrop on e-mail from suspected terrorists and other criminals"
    },
    {
        "word": "monitor",
        "british_pronunciation": "/ˈmɒn.ɪ.tər/",
        "british_audio_src": "monitor_gb.mp3",
        "american_pronunciation": "/ˈmɑː.nɪ.t̬ɚ/",
        "american_audio_src": "monitor_us.mp3",
        "sentence": "employers who want to monitor employee e-mail"
    },
    {
        "word": "omnibus",
        "british_pronunciation": "/ˈɒm.nɪ.bʌs/",
        "british_audio_src": "omnibus_gb.mp3",
        "american_pronunciation": "/ˈɑːm.nɪ.bʌs/",
        "american_audio_src": "omnibus_us.mp3",
        "sentence": "The United States Omnibus Crime Control and Safe Streets Act of 1968"
    },
    {
    "word": "surreptitious",
    "british_pronunciation": "/ˌsʌr.əpˈtɪʃ.əs/",
    "british_audio_src": "surreptitious_gb.mp3",
    "american_pronunciation": "/ˌsɜːr.əpˈtɪʃ.əs/",
    "american_audio_src": "surreptitious_us.mp3",
    "sentence": "engaging in surreptitious surveillance of employee activity through the use of electronic devices"
    },{
        "word": "surveillance",
        "british_pronunciation": "/səˈveɪ.ləns/",
        "british_audio_src": "surveillance_gb.mp3",
        "american_pronunciation": "/sɚˈveɪ.ləns/",
        "american_audio_src": "surveillance_us.mp3",
        "sentence": "engaging in surreptitious surveillance of employee activity through the use of electronic devices"
    },
    {
        "word": "outweigh",
        "british_pronunciation": "/ˌaʊtˈweɪ/",
        "british_audio_src": "outweigh_gb.mp3",
        "american_pronunciation": "/ˌaʊtˈweɪ/",
        "american_audio_src": "outweigh_us.mp3",
        "sentence": "an employee’s right to privacy does not outweigh a company’s rights and interests"
    },
    {
        "word": "retrieve",
        "british_pronunciation": "/rɪˈtriːv/",
        "british_audio_src": "retrieve_gb.mp3",
        "american_pronunciation": "/rɪˈtriːv/",
        "american_audio_src": "retrieve_us.mp3",
        "sentence": "investigators retrieved all the student’s e-mail from the archives of the e-mail server"
    },
    {
        "word": "expel",
        "british_pronunciation": "/ɪkˈspel/",
        "british_audio_src": "expel_gb.mp3",
        "american_pronunciation": "/ɪkˈspel/",
        "american_audio_src": "expel_us.mp3",
        "sentence": "The student was expelled from the university."
    },
    {
        "word": "spoof",
        "british_pronunciation": "/spuːf/",
        "british_audio_src": "spoof_gb.mp3",
        "american_pronunciation": "/spuf/",
        "american_audio_src": "spoof_us.mp3",
        "sentence": "if the e-mail had been “spoofed” to make it look as though he had sent it"
    },{
        "word": "snoop",
        "british_pronunciation": "/snuːp/",
        "british_audio_src": "snoop_gb.mp3",
        "american_pronunciation": "/snup/",
        "american_audio_src": "snoop_us.mp3",
        "sentence": "some organizations simply snoop on the off chance that important information might be discovered"
    },
    {
        "word": "off chance",
        "british_pronunciation": "/ɒf tʃɑːns/",
        "british_audio_src": "offchance_gb.mp3",
        "american_pronunciation": "/ɔːf tʃæns/",
        "american_audio_src": "offchance_us.mp3",
        "sentence": "some organizations simply snoop on the off chance that important information might be discovered"
    },
    {
        "word": "espionage",
        "british_pronunciation": "/ˈes.pi.ə.nɑːʒ/",
        "british_audio_src": "espionage_gb.mp3",
        "american_pronunciation": "/ˈes.pi.ə.nɑːʒ/",
        "american_audio_src": "espionage_us.mp3",
        "sentence": "Organizations also recognize a need to protect themselves from false rumors and industrial espionage."
    },
    {
        "word": "boot",
        "british_pronunciation": "/buːt/",
        "british_audio_src": "boot_gb.mp3",
        "american_pronunciation": "/but/",
        "american_audio_src": "boot_us.mp3",
        "sentence": "when the computer boots or a new user logs in"
    },
        {
        "word": "controversial",
        "british_pronunciation": "/kɒn.trəˈvɜː.ʃəl/",
        "british_audio_src": "controversial_gb.mp3",
        "american_pronunciation": "/ˌkɑːn.trəˈvɝː.ʃəl/",
        "american_audio_src": "controversialt_us.mp3",
        "sentence": "save your controversial comments for face-to-face conversations"
    },
]

# Generate word entries
word_entries = ""
for i, entry in enumerate(data):
    word_entries += word_entry_template.substitute(
        word=entry["word"],
        british_pronunciation=entry["british_pronunciation"],
        british_audio_src=entry["british_audio_src"],
        british_audio_id=f"audioBritish{i}",
        american_pronunciation=entry["american_pronunciation"],
        american_audio_src=entry["american_audio_src"],
        american_audio_id=f"audioAmerican{i}",
        sentence=entry["sentence"]
    )

# Fill the main template
filled_html = template.substitute(word_entries=word_entries)

# Save the filled HTML to a file
with open("filled.html", "w") as f:
    f.write(filled_html)

print("HTML generated and saved to 'filled.html'")
# Out:
# HTML generated and saved to 'filled.html'

# %%
import os
print(os.getcwd())
# Out:
# /Users/zhijungao/Desktop
