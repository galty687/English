# %%
import requests

def download_mp3(url, filename):
    response = requests.get(url)
    with open(filename, 'wb') as file:
        file.write(response.content)

# British English Pronunciations
download_mp3('https://s3.eu-west-1.amazonaws.com/com.idmgroup.oed100.sounds.prod/mp3/m/ma/mas/mastermind__gb_2.mp3', 'mastermind_british_1.mp3')
download_mp3('https://s3.eu-west-1.amazonaws.com/com.idmgroup.oed100.sounds.prod/mp3/m/ma/mas/mastermind__gb_4.mp3', 'mastermind_british_2.mp3')

# U.S. English Pronunciation
download_mp3('https://s3.eu-west-1.amazonaws.com/com.idmgroup.oed100.sounds.prod/mp3/m/ma/mas/mastermind__us_4.mp3', 'mastermind_american.mp3')

# %%
from string import Template

# Define the HTML template
with open("template.html", "r") as f:
    template_str = f.read()
    template = Template(template_str)

# Define the word entry template
word_entry_template = Template("""
<div class="word-container">
    <div class="word">$word</div>
    <div class="pronunciation-container">
        <div class="pronunciation-box">
            <div class="pronunciation-label">British Pronunciation</div>
            <div class="pronunciation">$british_pronunciation</div>
            <button class="play-button" onclick="playSound('$british_audio_id')">Play Sound</button>
            <audio id="$british_audio_id" src="audio/$british_audio_src"></audio>
        </div>
        <div class="pronunciation-box">
            <div class="pronunciation-label">American Pronunciation</div>
            <div class="pronunciation">$american_pronunciation</div>
            <button class="play-button" onclick="playSound('$american_audio_id')">Play Sound</button>
            <audio id="$american_audio_id" src="audio/$american_audio_src"></audio>
        </div>
    </div>
    <div class="sentence">$sentence</div>
    <button class="translation-button" onclick="toggleTranslation(this)">Show Translation</button>
    <div class="hidden">$translation</div>
</div>
""")

# Sample data
data = [
    {
        "word": "intangible",
        "british_pronunciation": "/ɪnˈtændʒɪbl/",
        "british_audio_src": "intangible_gb.mp3",
        "american_pronunciation": "/ɪnˈtændʒəbl/",
        "american_audio_src": "intangible_us.mp3",
        "sentence": "As the intangible enabler of communications, media, and software, it lacks physical substance.",
        "translation": "无形的"
    },
    {
        "word": "subsume",
        "british_pronunciation": "/səbˈsjuːm/",
        "british_audio_src": "subsume_gb.mp3",
        "american_pronunciation": "/səbˈsuːm/",
        "american_audio_src": "subsume_us.mp3",
        "sentence": "It might subsume all the revolutions to come.",
        "translation": "包含"
    },
    {
        "word": "disparity",
        "british_pronunciation": "/dɪˈsparɪti/",
        "british_audio_src": "disparity_gb.mp3",
        "american_pronunciation": "/dɪˈspærəti/",
        "american_audio_src": "disparity_us.mp3",
        "sentence": "No one will worry about money, jobs, wealth disparities, or planning for old age.",
        "translation": "差异"
    },
    {
        "word": "automation",
        "british_pronunciation": "/ˌɔːtəˈmeɪʃn/",
        "british_audio_src": "automation_gb.mp3",
        "american_pronunciation": "/ˌɔːtəˈmeɪʃən/",
        "american_audio_src": "automation_us.mp3",
        "sentence": "How we can live in the long term with a high degree of automation.",
        "translation": "自动化"
    },
    {
        "word": "complaint",
        "british_pronunciation": "/kəmˈpleɪnt/",
        "british_audio_src": "complaint_gb.mp3",
        "american_pronunciation": "/kəmˈpleɪnt/",
        "american_audio_src": "complaint_us.mp3",
        "sentence": "I have presented complaints about the way digital technology interfaces with people.",
        "translation": "抱怨"
    },
    {
        "word": "dilute",
        "british_pronunciation": "/daɪˈluːt/",
        "british_audio_src": "dilute_gb.mp3",
        "american_pronunciation": "/daɪˈluːt/",
        "american_audio_src": "dilute_us.mp3",
        "sentence": "People are not just pointlessly diluting themselves on cultural, intellectual, and spiritual levels.",
        "translation": "稀释"
    },
    {
        "word": "fawn",
        "british_pronunciation": "/fɔːn/",
        "british_audio_src": "fawn_gb.mp3",
        "american_pronunciation": "/fɔːn/",
        "american_audio_src": "fawn_us.mp3",
        "sentence": "By fawning over digital superhuman phenomena that don’t necessarily exist.",
        "translation": "迷恋"
    },
    {
        "word": "alternate",
        "british_pronunciation": "/ˈɔːltəneɪt/",
        "british_audio_src": "alternate_gb.mp3",
        "american_pronunciation": "/ˈɔːltərˌneɪt/",
        "american_audio_src": "alternate_us.mp3",
        "sentence": "My goal is to portray an alternate future in which people are treated appropriately as being special.",
        "translation": "替代的"
    },
    {
        "word": "glean",
        "british_pronunciation": "/ɡliːn/",
        "british_audio_src": "glean_gb.mp3",
        "american_pronunciation": "/ɡliːn/",
        "american_audio_src": "glean_us.mp3",
        "sentence": "Pay people for information gleaned from them if that information turns out to be valuable.",
        "translation": "收集"
    },
    {
        "word": "impoverish",
        "british_pronunciation": "/ɪmˈpɒvərɪʃ/",
        "british_audio_src": "impoverish_gb.mp3",
        "american_pronunciation": "/ɪmˈpɑːvərɪʃ/",
        "american_audio_src": "impoverish_us.mp3",
        "sentence": "Information wouldn’t need to be free if no one were impoverished.",
        "translation": "使贫穷"
    },
    {
        "word": "the lion’s share of",
        "british_pronunciation": "/ðə ˈlaɪənz ʃɛər ʌv/",
        "british_audio_src": "the_lions_share_of_gb.mp3",
        "american_pronunciation": "/ði ˈlaɪənz ʃɛr əv/",
        "american_audio_src": "the_lions_share_of_us.mp3",
        "sentence": "But the lion’s share of wealth now flows to those who aggregate and route those offerings.",
        "translation": "最大份额"
    },
    {
        "word": "aggregate",
        "british_pronunciation": "/ˈæɡrɪɡeɪt/",
        "british_audio_src": "aggregate_gb.mp3",
        "american_pronunciation": "/ˈæɡrɪɡeɪt/",
        "american_audio_src": "aggregate_us.mp3",
        "sentence": "But the lion’s share of wealth now flows to those who aggregate and route those offerings.",
        "translation": "聚集"
    },
    {
        "word": "route",
        "british_pronunciation": "/ruːt/",
        "british_audio_src": "route_gb.mp3",
        "american_pronunciation": "/raʊt/",
        "american_audio_src": "route_us.mp3",
        "sentence": "But the lion’s share of wealth now flows to those who aggregate and route those offerings.",
        "translation": "路线"
    },
    {
        "word": "trinket",
        "british_pronunciation": "/ˈtrɪŋkɪt/",
        "british_audio_src": "trinket_gb.mp3",
        "american_pronunciation": "/ˈtrɪŋkɪt/",
        "american_audio_src": "trinket_us.mp3",
        "sentence": "Trinkets tossed into the crowd spread illusions.",
        "translation": "小装饰品"
    },
    {
        "word": "disenfranchisement",
        "british_pronunciation": "/ˌdɪsɪnˈfræntʃaɪzmənt/",
        "british_audio_src": "disenfranchisement_gb.mp3",
        "american_pronunciation": "/ˌdɪsɪnˈfræntʃaɪzmənt/",
        "american_audio_src": "disenfranchisement_us.mp3",
        "sentence": "Then a massive disenfranchisement will take place.",
        "translation": "剥夺权利"
    },
    {
        "word": "apocalyptic",
        "british_pronunciation": "/əˌpɒkəˈlɪptɪk/",
        "british_audio_src": "apocalyptic_gb.mp3",
        "american_pronunciation": "/əˌpɑːkəˈlɪptɪk/",
        "american_audio_src": "apocalyptic_us.mp3",
        "sentence": "The old specter of a thousand science fiction tales and Marxist nightmares will be brought back from the dead and empowered to apocalyptic proportions.",
        "translation": "世界末日的"
    },
    {
        "word": "groove",
        "british_pronunciation": "/ɡruːv/",
        "british_audio_src": "groove_gb.mp3",
        "american_pronunciation": "/ɡruːv/",
        "american_audio_src": "groove_us.mp3",
        "sentence": "Digital technologists are setting down the new grooves of how people live.",
        "translation": "凹槽"
    },
    {
    "word": "utopian",
    "british_pronunciation": "/juːˈtəʊpiən/",
    "british_audio_src": "utopian_gb.mp3",
    "american_pronunciation": "/juːˈtoʊpiən/",
    "american_audio_src": "utopian_us.mp3",
    "sentence": "They’re doing it according to the expectations of foolish utopian scenarios.",
    "translation": "乌托邦的"
    },
    {
        "word": "scenario",
        "british_pronunciation": "/sɪˈnɛəriəʊ/",
        "british_audio_src": "scenario_gb.mp3",
        "american_pronunciation": "/səˈnɛərioʊ/",
        "american_audio_src": "scenario_us.mp3",
        "sentence": "They’re doing it according to the expectations of foolish utopian scenarios.",
        "translation": "情景"
    },
    {
        "word": "crack",
        "british_pronunciation": "/kræk/",
        "british_audio_src": "crack_gb.mp3",
        "american_pronunciation": "/kræk/",
        "american_audio_src": "crack_us.mp3",
        "sentence": "People are cracking the inner codes of biology.",
        "translation": "破解"
    }



]

# Generate word entries
word_entries = ""
for i, entry in enumerate(data):
    word_entries += word_entry_template.substitute(
        word=entry["word"],
        british_pronunciation=entry["british_pronunciation"],
        british_audio_src=entry["british_audio_src"],
        british_audio_id=f"audioBritish{i}",
        american_pronunciation=entry["american_pronunciation"],
        american_audio_src=entry["american_audio_src"],
        american_audio_id=f"audioAmerican{i}",
        sentence=entry.get("sentence", "No sentence available"),
        translation=entry.get("translation", "No translation available")

    )

# Fill the main template
filled_html = template.substitute(word_entries=word_entries)

# Save the filled HTML to a file
with open("filled.html", "w") as f:
    f.write(filled_html)

print("HTML generated and saved to 'filled.html'")
# Out:
# HTML generated and saved to 'filled.html'

# %%
import os
print(os.getcwd())
# Out:
# /Users/zhijungao/Desktop
